# %% [markdown]
# ## Initialize packages

# %%
begin
	using Colors, ColorVectorSpace, ImageShow, FileIO, ImageIO
	using PlutoUI
	using HypertextLiteral
end
# Out:
# ┌ Info: Precompiling ColorVectorSpace [c3611d14-8923-5661-9e6a-0046d554d3a4]
# └ @ Base loading.jl:1664
# ┌ Info: Precompiling ImageShow [4e3cecfd-b093-5904-9786-8bbb286a6a31]
# └ @ Base loading.jl:1664

# %% [markdown]
# ## Data: Images
#
# Use `Images.jl` to load an image file in 3 steps:
#
# 1. Specify URL to download from
# 2. Download the image file to computer
# 3. Use `Images.jl` to load file

# %%
# url 
url = "https://user-images.githubusercontent.com/6933510/107239146-dcc3fd00-6a28-11eb-8c7b-41aaf6618935.png" 

# download 
philip_filename = download(url) # download to a local file. The filename is returned 

# load 
philip = load(philip_filename)
# Out:
# ┌ Info: Precompiling PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883]
# └ @ Base loading.jl:1664
# 864×700 Array{RGB{N0f8},2} with eltype RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.157,0.141,0.106)  …  RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.157,0.141,0.106)     RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.157,0.141,0.106)     RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.157,0.141,0.106)     RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.145,0.129,0.094)     RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.145,0.129,0.094)  …  RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.145,0.129,0.094)     RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.145,0.129,0.094)     RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.145,0.129,0.094)     RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.145,0.129,0.094)     RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.145,0.129,0.094)  …  RGB{N0f8}(0.702,0.722,0.737)
#  RGB{N0f8}(0.145,0.129,0.094)     RGB{N0f8}(0.702,0.722,0.737)
# ...

# %% [markdown]
# Exercise:
#
# - change URL
# - download file already on computer

# %%
url = "https://bestpetsvet.com/wp-content/uploads/2019/02/cat-2146089_1280.jpg" ; 

cat_file = download(url) ; 

cat = load(cat_file)
# Out:
# 853×1280 Array{RGB{N0f8},2} with eltype RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.043,0.039,0.031)  …  RGB{N0f8}(0.043,0.035,0.039)
#  RGB{N0f8}(0.039,0.035,0.027)     RGB{N0f8}(0.039,0.031,0.035)
#  RGB{N0f8}(0.035,0.031,0.024)     RGB{N0f8}(0.039,0.031,0.035)
#  RGB{N0f8}(0.035,0.031,0.024)     RGB{N0f8}(0.039,0.031,0.035)
#  RGB{N0f8}(0.035,0.031,0.024)     RGB{N0f8}(0.039,0.031,0.035)
#  RGB{N0f8}(0.035,0.031,0.024)  …  RGB{N0f8}(0.039,0.031,0.035)
#  RGB{N0f8}(0.035,0.031,0.024)     RGB{N0f8}(0.039,0.031,0.035)
#  RGB{N0f8}(0.035,0.031,0.024)     RGB{N0f8}(0.035,0.027,0.031)
#  RGB{N0f8}(0.031,0.027,0.02)      RGB{N0f8}(0.047,0.031,0.027)
#  RGB{N0f8}(0.035,0.031,0.024)     RGB{N0f8}(0.051,0.035,0.031)
#  RGB{N0f8}(0.035,0.031,0.024)  …  RGB{N0f8}(0.051,0.035,0.031)
#  RGB{N0f8}(0.031,0.027,0.02)      RGB{N0f8}(0.051,0.035,0.031)
#  RGB{N0f8}(0.035,0.031,0.024)     RGB{N0f8}(0.051,0.035,0.031)
#  ⋮                             ⋱
# ...

# %%
penguin = load("cute-baby-penguin.jpg")
# Out:
# 1024×1024 Array{RGB{N0f8},2} with eltype RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.196,0.188,0.208)  …  RGB{N0f8}(0.792,0.796,0.765)
#  RGB{N0f8}(0.204,0.196,0.216)     RGB{N0f8}(0.792,0.796,0.765)
#  RGB{N0f8}(0.2,0.192,0.212)       RGB{N0f8}(0.788,0.792,0.761)
#  RGB{N0f8}(0.2,0.192,0.212)       RGB{N0f8}(0.788,0.792,0.761)
#  RGB{N0f8}(0.2,0.192,0.212)       RGB{N0f8}(0.784,0.788,0.757)
#  RGB{N0f8}(0.2,0.192,0.212)    …  RGB{N0f8}(0.784,0.788,0.757)
#  RGB{N0f8}(0.2,0.192,0.204)       RGB{N0f8}(0.792,0.792,0.761)
#  RGB{N0f8}(0.204,0.196,0.208)     RGB{N0f8}(0.788,0.788,0.757)
#  RGB{N0f8}(0.212,0.204,0.216)     RGB{N0f8}(0.812,0.8,0.78)
#  RGB{N0f8}(0.204,0.196,0.208)     RGB{N0f8}(0.812,0.8,0.78)
#  RGB{N0f8}(0.2,0.192,0.204)    …  RGB{N0f8}(0.812,0.8,0.78)
#  RGB{N0f8}(0.2,0.192,0.204)       RGB{N0f8}(0.816,0.804,0.784)
#  RGB{N0f8}(0.2,0.192,0.204)       RGB{N0f8}(0.82,0.808,0.788)
#  ⋮                             ⋱
# ...

# %% [markdown]
# ## Inspecting data
#
# Determine size of the image. The first number is height, the second number is width:

# %%
philip_size   = size(philip) 
println(philip_size)
philip_height = philip_size[1] 
println(philip_height)
philip_width  = philip_size[2] 
println(philip_width)
# Out:
# (864, 700)
# 864
# 700
